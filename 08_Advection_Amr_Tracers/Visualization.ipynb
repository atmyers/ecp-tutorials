# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ds = AMReXDataset("ecp-tutorials/build/07_Advection_EB/plt00120")
# Out:
# yt : [INFO     ] 2021-04-13 11:53:11,218 Parameters: current_time              = 1.3240705248615918
# yt : [INFO     ] 2021-04-13 11:53:11,219 Parameters: domain_dimensions         = [64 64  8]
# yt : [INFO     ] 2021-04-13 11:53:11,220 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-04-13 11:53:11,221 Parameters: domain_right_edge         = [1.    1.    0.125]

# %%
ds.field_list
# Out:
# [('all', 'particle_cpu'),
#  ('all', 'particle_id'),
#  ('all', 'particle_position_x'),
#  ('all', 'particle_position_y'),
#  ('all', 'particle_position_z'),
#  ('all', 'particle_real_comp0'),
#  ('all', 'particle_real_comp1'),
#  ('all', 'particle_real_comp2'),
#  ('all', 'particle_real_comp3'),
#  ('boxlib', 'phi'),
#  ('boxlib', 'proc'),
#  ('boxlib', 'vfrac'),
#  ('boxlib', 'xvel'),
#  ('boxlib', 'yvel'),
#  ('boxlib', 'zvel'),
#  ('particles', 'particle_cpu'),
#  ('particles', 'particle_id'),
#  ('particles', 'particle_position_x'),
#  ('particles', 'particle_position_y'),
#  ('particles', 'particle_position_z'),
#  ('particles', 'particle_real_comp0'),
#  ('particles', 'particle_real_comp1'),
#  ('particles', 'particle_real_comp2'),
#  ('particles', 'particle_real_comp3')]

# %%
sl = yt.SlicePlot(ds, 2, ('boxlib', 'phi'))
sl.annotate_particles(ds.domain_width[2], stride=10, marker='.')
# Out:
# yt : [INFO     ] 2021-04-13 11:53:13,056 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-13 11:53:13,057 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-13 11:53:13,058 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-13 11:53:13,059 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-13 11:53:13,061 Making a fixed resolution buffer of (('boxlib', 'phi')) 800 by 800
# yt : [WARNING  ] 2021-04-13 11:53:13,118 Plot image for field ('boxlib', 'phi') has both positive and negative/zero values. Min = -1.000000, Max = 1.021305.
# yt : [WARNING  ] 2021-04-13 11:53:13,118 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
