# %%
import yt

# %%
ds = yt.load("plot")
# Out:
# yt : [INFO     ] 2021-04-15 13:12:23,700 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-04-15 13:12:23,702 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-04-15 13:12:23,702 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-04-15 13:12:23,703 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
sl = yt.SlicePlot(ds, 2, 'density')
# Out:
# yt : [INFO     ] 2021-04-15 13:12:25,113 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-15 13:12:25,114 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-15 13:12:25,115 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-15 13:12:25,116 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-04-15 13:12:25,118 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
sl.annotate_grids()
# Out:
# /Users/atmyers/yt-conda/lib/python3.8/site-packages/unyt-2.8.0-py3.8.egg/unyt/array.py:1778: RuntimeWarning: invalid value encountered in true_divide
#   out_arr = func(
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
